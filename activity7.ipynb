# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import warnings 
warnings.filterwarnings('ignore')
import folium
from folium.plugins import HeatMap

# %%
df = pd.read_csv('datasets\\Chicago_Crimes.csv')
df
# Out:
#               ID Case Number                    Date                  Block  \
# 0       13439321    JH237424  04/14/2024 12:00:00 AM    040XX S PRAIRIE AVE
# 1       13437420    JH234779  04/14/2024 12:00:00 AM      023XX W CERMAK RD
# 2       13428676    JH224478  04/14/2024 12:00:00 AM    043XX W LE MOYNE ST
# 3       13429357    JH225293  04/14/2024 12:00:00 AM       039XX W ADAMS ST
# 4       13430098    JH226395  04/14/2024 12:00:00 AM       011XX W 112TH PL
# ...          ...         ...                     ...                    ...
# 249118  13805239    JJ217509  04/12/2025 12:00:00 AM     029XX W LOGAN BLVD
# 249119  13804023    JJ215813  04/12/2025 12:00:00 AM    094XX S HARVARD AVE
# 249120  13803926    JJ215943  04/12/2025 12:00:00 AM  084XX S VINCENNES AVE
# 249121  13803475    JJ215338  04/12/2025 12:00:00 AM    050XX S ABERDEEN ST
# 249122  13804512    JJ216668  04/12/2025 12:00:00 AM    012XX W CARROLL AVE
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 249123 entries, 0 to 249122
# Data columns (total 22 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   ID                    249123 non-null  int64
#  1   Case Number           249123 non-null  object
#  2   Date                  249123 non-null  object
#  3   Block                 249123 non-null  object
#  4   IUCR                  249123 non-null  object
#  5   Primary Type          249123 non-null  object
#  6   Description           249123 non-null  object
#  7   Location Description  248266 non-null  object
#  8   Arrest                249123 non-null  bool
#  9   Domestic              249123 non-null  bool
#  10  Beat                  249123 non-null  int64
#  11  District              249123 non-null  int64
#  12  Ward                  249123 non-null  int64
#  13  Community Area        249120 non-null  float64
# ...

# %%
df['ID'] = df['ID'].astype('category')
df['Case Number'] = df['Case Number'].astype('category')
df['Date'] = df['Date'].astype('category')
df['Block'] = df['Block'].astype('category')
df['IUCR'] = df['IUCR'].astype('category')
df['Year'] = df['Year'].astype('category')
df['Location Description'] = df['Location Description'].astype('category')
df['District'] = df['District'].astype('category')
df['Ward'] = df['Ward'].astype('category')
df['FBI Code'] = df['FBI Code'].astype('category')

# %%
df.columns
# Out:
# Index(['ID', 'Case Number', 'Date', 'Block', 'IUCR', 'Primary Type',
#        'Description', 'Location Description', 'Arrest', 'Domestic', 'Beat',
#        'District', 'Ward', 'Community Area', 'FBI Code', 'X Coordinate',
#        'Y Coordinate', 'Year', 'Updated On', 'Latitude', 'Longitude',
#        'Location'],
#       dtype='object')

# %%
df['Primary Type'].value_counts()
# Out:
# Primary Type
# THEFT                                59201
# BATTERY                              44579
# CRIMINAL DAMAGE                      27094
# ASSAULT                              22615
# MOTOR VEHICLE THEFT                  19604
# OTHER OFFENSE                        16781
# DECEPTIVE PRACTICE                   14991
# BURGLARY                              8443
# ROBBERY                               8200
# WEAPONS VIOLATION                     7164
# NARCOTICS                             6627
# CRIMINAL TRESPASS                     5045
# OFFENSE INVOLVING CHILDREN            1597
# CRIMINAL SEXUAL ASSAULT               1573
# SEX OFFENSE                           1210
# PUBLIC PEACE VIOLATION                1006
# INTERFERENCE WITH PUBLIC OFFICER       771
# HOMICIDE                               553
# STALKING                               520
# ARSON                                  452
# PROSTITUTION                           287
# ...

# %%
THEFT = df[df['Primary Type']=='THEFT']
BATTERY = df[df['Primary Type']=='BATTERY']
CRIMINALDAMAGE = df[df['Primary Type']=='CRIMINAL DAMAGE']
ASSAULT = df[df['Primary Type']=='ASSAULT']
MOTORVEHICLETHEFT = df[df['Primary Type']=='MOTOR VEHICLE THEFT']
OTHEROFFENSE = df[df['Primary Type']=='OTHER OFFENSE']
DECEPTIVEPRACTICE = df[df['Primary Type']=='DECEPTIVE PRACTICE']
BURGLARY = df[df['Primary Type']=='BURGLARY']
ROBBERY = df[df['Primary Type']=='ROBBERY']
WEAPONSVIOLATION = df[df['Primary Type']=='WEAPONS VIOLATION']
NARCOTICS = df[df['Primary Type']=='NARCOTICS']
CRIMINALTRESPASS = df[df['Primary Type']=='CRIMINAL TRESPASS']
OFFENSEINVOLVINGCHILDREN = df[df['Primary Type']=='OFFENSE INVOLVING CHILDREN']
CRIMINALSEXUALASSAULT = df[df['Primary Type']=='CRIMINAL SEXUAL ASSAULT']
SEXOFFENSE = df[df['Primary Type']=='SEX OFFENSE']
PUBLICPEACEVIOLATION = df[df['Primary Type']=='PUBLIC PEACE VIOLATION']
INTERFERENCEWITHPUBLIC_OFFICER = df[df['Primary Type']=='INTERFERENCE WITH PUBLIC OFFICER']
HOMICIDE = df[df['Primary Type']=='HOMICIDE']
STALKING = df[df['Primary Type']=='STALKING']
ARSON = df[df['Primary Type']=='ARSON']
PROSTITUTION = df[df['Primary Type']=='PROSTITUTION']
CONCEALEDCARRYLICENSEVIOLATION = df[df['Primary Type']=='CONCEALED CARRY LICENSE VIOLATION']
LIQUORLAWVIOLATION = df[df['Primary Type']=='LIQUOR LAW VIOLATION']
INTIMIDATION = df[df['Primary Type']=='INTIMIDATION']
KIDNAPPING = df[df['Primary Type']=='KIDNAPPING']
OBSCENITY = df[df['Primary Type']=='OBSCENITY']
HUMANTRAFFICKING = df[df['Primary Type']=='HUMAN TRAFFICKING']
GAMBLING = df[df['Primary Type']=='GAMBLING']
PUBLICINDECENCY = df[df['Primary Type']=='PUBLIC INDECENCY']
OTHER_NARCOTICVIOLATION = df[df['Primary Type']=='OTHER NARCOTIC VIOLATION']
NONCRIMINAL = df[df['Primary Type']=='NON-CRIMINAL']

# %%
THEFTloc = THEFT[THEFT['Location Description'] == "APARTMENT"]
THEFTlocarrest = THEFTloc[THEFTloc['Arrest'] == 1]
THEFTlocarrest
# Out:
#               ID Case Number                    Date                   Block  \
# 4059    13436974    JH234595  04/19/2024 08:00:00 PM        005XX N NOBLE ST
# 6886    13438851    JH236825  04/23/2024 11:00:00 PM     073XX S CRANDON AVE
# 9700    13460501    JH263678  04/28/2024 03:00:00 AM         038XX W 18TH ST
# 11643   13445893    JH245427  04/30/2024 09:30:00 PM    090XX S ESCANABA AVE
# 15476   13451413    JH252231  05/06/2024 07:20:00 AM    077XX S JEFFERY BLVD
# ...          ...         ...                     ...                     ...
# 228208  13769576    JJ174517  03/09/2025 04:00:00 AM  046XX N CUMBERLAND AVE
# 228292  13769875    JJ174656  03/09/2025 09:15:00 AM         009XX E 80TH ST
# 239600  13787822    JJ196355  03/27/2025 09:45:00 AM   110XX S WENTWORTH AVE
# 244345  13795369    JJ205450  04/04/2025 01:08:00 AM   015XX N MASSASOIT AVE
# 245175  13796881    JJ207302  04/05/2025 11:00:00 AM      087XX S BURLEY AVE
#
# ...

# %%
heatmap1 = THEFTlocarrest.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap1data = heatmap1[['Latitude','Longitude','incident_count']].values.tolist()
map1 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)
HeatMap(heatmap1data).add_to(map1)

# %%
map1.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map1
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
BATTERYdescription = BATTERY[BATTERY['Description'] == "AGGRAVATED - OTHER FIREARM"]

heatmap2 = BATTERYdescription.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap2data = heatmap2[['Latitude','Longitude','incident_count']].values.tolist()
map2 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap2data).add_to(map2)

# %%
map2.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map2
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
CRIMINALDAMAGEstreet = CRIMINALDAMAGE[CRIMINALDAMAGE['Location Description'] == "STREET"]
CRIMINALDAMAGEstreet2025 = CRIMINALDAMAGEstreet[CRIMINALDAMAGEstreet['Year']== 2025]
CRIMINALDAMAGEstreet2025arrested = CRIMINALDAMAGEstreet2025[CRIMINALDAMAGEstreet2025['Arrest']==1]

heatmap3 = CRIMINALDAMAGEstreet2025arrested.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap3data = heatmap3[['Latitude','Longitude','incident_count']].values.tolist()
map3 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap3data).add_to(map3)

# %%
map3.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map3
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ASSAULT1 = ASSAULT[ASSAULT['Arrest'] == 1]
ASSAULT11 = ASSAULT1[ASSAULT1['Domestic']== 1]
ASSAULT112025 = ASSAULT11[ASSAULT11['Year']== 2025]

heatmap4 = ASSAULT112025.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap4data = heatmap4[['Latitude','Longitude','incident_count']].values.tolist()
map4 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap4data).add_to(map4)

# %%
map4.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map4
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
MOTORVEHICLETHEFTbikewvin = MOTORVEHICLETHEFT[MOTORVEHICLETHEFT['Description'] == "THEFT / RECOVERY - CYCLE, SCOOTER, BIKE WITH VIN"]

heatmap5 = MOTORVEHICLETHEFTbikewvin.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap5data = heatmap5[['Latitude','Longitude','incident_count']].values.tolist()
map5 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap5data).add_to(map5)

# %%
map5.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map5
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
OTHEROFFENSEboardplaneweapon = OTHEROFFENSE[OTHEROFFENSE['Description'] == "BOARD PLANE WITH WEAPON"]

heatmap6 = OTHEROFFENSEboardplaneweapon.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap6data = heatmap6[['Latitude','Longitude','incident_count']].values.tolist()
map6 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap6data).add_to(map6)

# %%
map6.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map6
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
DECEPTIVEPRACTICEunlawfuluser = DECEPTIVEPRACTICE[DECEPTIVEPRACTICE['Description'] == "UNLAWFUL USE OF A COMPUTER"]

heatmap7 = DECEPTIVEPRACTICEunlawfuluser.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap7data = heatmap7[['Latitude','Longitude','incident_count']].values.tolist()
map7 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap7data).add_to(map7)

# %%
map7.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map7
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
BURGLARYhomeinvasion = BURGLARY[BURGLARY['Description'] == "HOME INVASION"]
BURGLARYhomeinvasionarrested = BURGLARYhomeinvasion[BURGLARYhomeinvasion['Arrest']== 1]

heatmap8 = BURGLARYhomeinvasionarrested.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap8data = heatmap8[['Latitude','Longitude','incident_count']].values.tolist()
map8 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap8data).add_to(map8)

# %%
map8.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map8
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ROBBERYstreeet = ROBBERY[ROBBERY['Location Description'] == "STREET"]
ROBBERYstreeetaggravated = ROBBERYstreeet[ROBBERYstreeet['Description']== "AGGRAVATED"]

heatmap9 = ROBBERYstreeetaggravated.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap9data = heatmap9[['Latitude','Longitude','incident_count']].values.tolist()
map9 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap9data).add_to(map9)

# %%
map9.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map9
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
WEAPONSVIOLATIONapartment = WEAPONSVIOLATION[WEAPONSVIOLATION['Location Description'] == "APARTMENT"]
WEAPONSVIOLATIONapartmenthandgun = WEAPONSVIOLATIONapartment[WEAPONSVIOLATIONapartment['Description']== "UNLAWFUL POSSESSION - HANDGUN"]

heatmap10 = WEAPONSVIOLATIONapartmenthandgun.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap10data = heatmap10[['Latitude','Longitude','incident_count']].values.tolist()
map10 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap10data).add_to(map10)

# %%
map10.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map10
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
NARCOTICSalley = NARCOTICS[NARCOTICS['Location Description']== "ALLEY"]
NARCOTICSalleyarrested = NARCOTICSalley[NARCOTICSalley['Arrest']== 1]
NARCOTICSalleyarrestedcocaine = NARCOTICSalleyarrested[NARCOTICSalleyarrested['Description']== "POSSESS - COCAINE"]

heatmap11 = NARCOTICSalleyarrestedcocaine.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap11data = heatmap11[['Latitude','Longitude','incident_count']].values.tolist()
map11 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap11data).add_to(map11)

# %%
map11.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map11
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
CRIMINALTRESPASSresidence = CRIMINALTRESPASS[CRIMINALTRESPASS['Description']== "TO RESIDENCE"]
CRIMINALTRESPASSresidence2 = CRIMINALTRESPASSresidence[CRIMINALTRESPASSresidence['Location Description']== "RESIDENCE"]
CRIMINALTRESPASSresidence2arrested = CRIMINALTRESPASSresidence2[CRIMINALTRESPASSresidence2['Arrest']== 1]

heatmap12 = CRIMINALTRESPASSresidence2arrested.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap12data = heatmap12[['Latitude','Longitude','incident_count']].values.tolist()
map12 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap12data).add_to(map12)

# %%
map12.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map12
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
OFFENSEINVOLVINGCHILDRENabduction = OFFENSEINVOLVINGCHILDREN[OFFENSEINVOLVINGCHILDREN['Description']== "CHILD ABDUCTION"]

heatmap13 = OFFENSEINVOLVINGCHILDRENabduction.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap13data = heatmap13[['Latitude','Longitude','incident_count']].values.tolist()
map13 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap13data).add_to(map13)

# %%
map13.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map13
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
CRIMINALSEXUALASSAULTstreet = CRIMINALSEXUALASSAULT[CRIMINALSEXUALASSAULT['Location Description']== "STREET"]

heatmap14 = CRIMINALSEXUALASSAULTstreet.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap14data = heatmap14[['Latitude','Longitude','incident_count']].values.tolist()
map14 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap14data).add_to(map14)

# %%
map14.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map14
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
SEXOFFENSEschool = SEXOFFENSE[SEXOFFENSE['Location Description']== "SCHOOL - PUBLIC BUILDING"]

heatmap15 = SEXOFFENSEschool.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap15data = heatmap15[['Latitude','Longitude','incident_count']].values.tolist()
map15 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap15data).add_to(map15)

# %%
map15.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map15
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
PUBLICPEACEVIOLATIONresidence = PUBLICPEACEVIOLATION[PUBLICPEACEVIOLATION['Location Description']== "RESIDENCE"]

heatmap16 = PUBLICPEACEVIOLATIONresidence.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap16data = heatmap16[['Latitude','Longitude','incident_count']].values.tolist()
map16 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap16data).add_to(map16)

# %%
map16.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map16
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
INTERFERENCEWITHPUBLIC_OFFICER2025 = INTERFERENCEWITHPUBLIC_OFFICER[INTERFERENCEWITHPUBLIC_OFFICER['Year']==2025]

heatmap17 = INTERFERENCEWITHPUBLIC_OFFICER2025.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap17data = heatmap17[['Latitude','Longitude','incident_count']].values.tolist()
map17 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap17data).add_to(map17)

# %%
map17.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map17
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
HOMICIDEalley = HOMICIDE[HOMICIDE['Location Description']== "ALLEY"]

heatmap18 = HOMICIDEalley.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap18data = heatmap18[['Latitude','Longitude','incident_count']].values.tolist()
map18 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap18data).add_to(map18)

# %%
map18.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map18
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
STALKINGsidewalk = STALKING[STALKING['Location Description']== "SIDEWALK"]

heatmap19 = STALKINGsidewalk.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap19data = heatmap19[['Latitude','Longitude','incident_count']].values.tolist()
map19 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap19data).add_to(map19)

# %%
map19.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map19
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
ARSONresidence = ARSON[ARSON['Location Description']== "RESIDENCE"]

heatmap20 = ARSONresidence.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap20data = heatmap20[['Latitude','Longitude','incident_count']].values.tolist()
map20 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap20data).add_to(map20)

# %%
map20.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map20
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
PROSTITUTIONsidwalk = PROSTITUTION[PROSTITUTION['Location Description']== "SIDEWALK"]

heatmap21 = PROSTITUTIONsidwalk.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap21data = heatmap21[['Latitude','Longitude','incident_count']].values.tolist()
map21 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap21data).add_to(map21)

# %%
map21.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map21
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
CONCEALEDCARRYLICENSEVIOLATIONpark = CONCEALEDCARRYLICENSEVIOLATION[CONCEALEDCARRYLICENSEVIOLATION['Location Description']== "PARK PROPERTY"]

heatmap22 = CONCEALEDCARRYLICENSEVIOLATIONpark.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap22data = heatmap22[['Latitude','Longitude','incident_count']].values.tolist()
map22 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap22data).add_to(map22)

# %%
map22.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map22
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
LIQUORLAWVIOLATIONbar = LIQUORLAWVIOLATION[LIQUORLAWVIOLATION['Location Description']== "BAR OR TAVERN"]

heatmap23 = LIQUORLAWVIOLATIONbar.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap23data = heatmap23[['Latitude','Longitude','incident_count']].values.tolist()
map23 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap23data).add_to(map23)

# %%
map23.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map23
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
INTIMIDATIONapartment = INTIMIDATION[INTIMIDATION['Location Description']== "APARTMENT"]

heatmap24 = INTIMIDATIONapartment.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap24data = heatmap24[['Latitude','Longitude','incident_count']].values.tolist()
map24 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap24data).add_to(map24)

# %%
map24.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map24
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
KIDNAPPINGsidewalk = KIDNAPPING[KIDNAPPING['Location Description']== "SIDEWALK"]

heatmap25 = KIDNAPPINGsidewalk.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap25data = heatmap25[['Latitude','Longitude','incident_count']].values.tolist()
map25 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap25data).add_to(map25)

# %%
map25.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map25
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
OBSCENITYapartment = OBSCENITY[OBSCENITY['Location Description']== "APARTMENT"]

heatmap26 = OBSCENITYapartment.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap26data = heatmap26[['Latitude','Longitude','incident_count']].values.tolist()
map26 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap26data).add_to(map26)

# %%
map26.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map26
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
HUMANTRAFFICKINGresidence = HUMANTRAFFICKING[HUMANTRAFFICKING['Location Description']== "RESIDENCE"]

heatmap27 = HUMANTRAFFICKINGresidence.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap27data = heatmap27[['Latitude','Longitude','incident_count']].values.tolist()
map27 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap27data).add_to(map27)

# %%
map27.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map27
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
GAMBLINGsidewalk = GAMBLING[GAMBLING['Location Description']== "SIDEWALK"]

heatmap28 = GAMBLINGsidewalk.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap28data = heatmap28[['Latitude','Longitude','incident_count']].values.tolist()
map28 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap28data).add_to(map28)

# %%
map28.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map28
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
heatmap29 = PUBLICINDECENCY.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap29data = heatmap29[['Latitude','Longitude','incident_count']].values.tolist()
map29 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap29data).add_to(map29)

# %%
map29.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map29
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
heatmap30 = OTHER_NARCOTICVIOLATION.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap30data = heatmap30[['Latitude','Longitude','incident_count']].values.tolist()
map30 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap30data).add_to(map30)

# %%
map30.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map30
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
heatmap31 = NONCRIMINAL.groupby(['Latitude','Longitude']).size().reset_index(name="incident_count")
heatmap31data = heatmap31[['Latitude','Longitude','incident_count']].values.tolist()
map31 = folium.Map(location = [41.8781, -87.6298], zoom_start=8)

# %%
HeatMap(heatmap31data).add_to(map31)

# %%
map31.save('chicago_crimes.html')
print("Data Successfully saved to chicago_crimes.html")
map31
# Out:
# Data Successfully saved to chicago_crimes.html
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
